# %%
import sys
sys.path.append('..')

# %% [markdown]
# # DataGenerator test

# %%
from spinesTS.data import DataGenerator, DataTS
from spinesTS.plotting import plot1d

# %%
dg = DataGenerator()

# %% [markdown]
# ## trigonometry_ds

# %%
a = dg.trigonometry_ds(size=100, sin_cos_noise_fact=(0.4, 0.4, 0.2), random_state=0)
_ = plot1d(a, figsize=(6, 4), labels='predict')

# %% [markdown]
# ## white_noise

# %%
b = dg.white_noise(100, random_state=0)
_ = plot1d(b, figsize=(6, 4))

# %% [markdown]
# ## random_walk

# %%
c = dg.random_walk(size=100, started_zero=True, random_state=0)
_ = plot1d(c, figsize=(6, 4))

# %% [markdown]
# # built-in datasets test

# %%
from spinesTS.data import (
    LoadElectricDataSets, 
    LoadMessagesSentDataSets, 
    LoadMessagesSentHourDataSets, 
    LoadSupermarketIncoming,
    LoadWebSales,
    BuiltInSeriesData
)

# %% [markdown]
# ## get data via BuiltInSeriesData class
#
# Since the class returned by BuiltInSeriesData inherits from a pandas dataframe, it has all the methods and features of a pandas dataframe

# %%
builtin_data = BuiltInSeriesData()
# Out:
# +----+----------------------+----------------------------------------------------------------------+
# |    | ds name              | columns                                                              |
# +----+----------------------+----------------------------------------------------------------------+
# |  0 | ETTh1                | date, HUFL, HULL, MUFL, MULL, LUFL, LULL, OT                         |
# |  1 | ETTh2                | date, HUFL, HULL, MUFL, MULL, LUFL, LULL, OT                         |
# |  2 | ETTm1                | date, HUFL, HULL, MUFL, MULL, LUFL, LULL, OT                         |
# |  3 | ETTm2                | date, HUFL, HULL, MUFL, MULL, LUFL, LULL, OT                         |
# |  4 | Electric_Production  | date, value                                                          |
# |  5 | M3_monthly_FTS       | series_id, method_id, forecast, horizon, timestamp, origin_timestamp |
# |  6 | M3_monthly_TSTS      | series_id, category, value, timestamp                                |
# |  7 | M3_other_FTS         | series_id, method_id, forecast, horizon, timestamp, origin_timestamp |
# |  8 | M3_other_TSTS        | series_id, category, value, timestamp                                |
# |  9 | M3_quarterly_FTS     | series_id, method_id, forecast, horizon, timestamp, origin_timestamp |
# | 10 | M3_quarterly_TSTS    | series_id, category, value, timestamp                                |
# | 11 | M3_yearly_FTS        | series_id, method_id, forecast, horizon, timestamp, origin_timestamp |
# | 12 | M3_yearly_TSTS       | series_id, category, value, timestamp                                |
# | 13 | Messages_Sent        | date, ta, tb, tc                                                     |
# | 14 | Messages_Sent_Hour   | date, ta, tb, tc                                                     |
# | 15 | Supermarket_Incoming | date, goods_cnt                                                      |
# | 16 | Web_Sales            | date, type_a, type_b, sales_cnt                                      |
# +----+----------------------+----------------------------------------------------------------------+

# %%
# get ETTh1 dataset
builtin_data[0]
# Out:
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
#               OT
# 0      30.531000
# 1      27.787001
# 2      27.787001
# 3      25.044001
# 4      21.948000
# ...          ...
# 17415  10.904000
# 17416  11.044000
# 17417  10.271000
# 17418   9.778000
# 17419   9.567000
#
# [17420 rows x 8 columns]

# %%
# you can also get dataset through this way
builtin_data['ETTh1']
# Out:
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
#               OT
# 0      30.531000
# 1      27.787001
# 2      27.787001
# 3      25.044001
# 4      21.948000
# ...          ...
# 17415  10.904000
# 17416  11.044000
# 17417  10.271000
# 17418   9.778000
# 17419   9.567000
#
# [17420 rows x 8 columns]

# %%
type(builtin_data['ETTh1'])
# Out:
# spinesTS.data.base.DataTS

# %% [markdown]
# ## get data via shortcut functions

# %%
electric = LoadElectricDataSets()
sales = LoadWebSales()

# %%
electric
# Out:
#            date     value
# 0    1985-01-01   72.5052
# 1    1985-02-01   70.6720
# 2    1985-03-01   62.4502
# 3    1985-04-01   57.4714
# 4    1985-05-01   55.3151
# ..          ...       ...
# 392  2017-09-01   98.6154
# 393  2017-10-01   93.6137
# 394  2017-11-01   97.3359
# 395  2017-12-01  114.7212
# 396  2018-01-01  129.4048
#
# [397 rows x 2 columns]

# %%
sales
# Out:
#             date  type_a  type_b  sales_cnt
# 0     2015-12-26   36425   36827      73252
# 1     2015-12-27   34544   37851      72395
# 2     2015-12-28   49317   46108      95425
# 3     2015-12-29   41823   41846      83669
# 4     2015-12-30   39946   40041      79987
# ...          ...     ...     ...        ...
# 2084  2021-09-09    8234  101689     109923
# 2085  2021-09-10    7825   93044     100869
# 2086  2021-09-11    8461  107687     116148
# 2087  2021-09-12    8159  106152     114311
# 2088  2021-09-13    8881  114413     123294
#
# [2089 rows x 4 columns]

# %%
messages = LoadMessagesSentDataSets()
messages
# Out:
#            date      ta     tb     tc
# 0    2020-01-01  194343  52737  51446
# 1    2020-01-02  207725  56149  54437
# 2    2020-01-03  179798  56113  54318
# 3    2020-01-04  196651  63549  62115
# 4    2020-01-05  206737  65993  64416
# ..          ...     ...    ...    ...
# 597  2021-08-20  123051  28227  27419
# 598  2021-08-21  175442  29423  28698
# 599  2021-08-22  169774  29284  28585
# 600  2021-08-23  159922  32587  31645
# 601  2021-08-24  204492  31637  30665
#
# [602 rows x 4 columns]

# %%
message_hour = LoadMessagesSentHourDataSets()
message_hour
# Out:
#                      date     ta    tb    tc
# 0     2021-01-01 00:00:00   1681   941   931
# 1     2021-01-01 01:00:00    462   454   452
# 2     2021-01-01 02:00:00    285   277   277
# 3     2021-01-01 03:00:00    171   169   168
# 4     2021-01-01 04:00:00    196   194   194
# ...                   ...    ...   ...   ...
# 5659  2021-08-24 19:00:00  13500  1352  1319
# 5660  2021-08-24 20:00:00  13375  1561  1529
# 5661  2021-08-24 21:00:00  13467  1443  1421
# 5662  2021-08-24 22:00:00  13416   932   910
# 5663  2021-08-24 23:00:00  11372   692   678
#
# [5664 rows x 4 columns]
